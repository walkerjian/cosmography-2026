# %% [markdown]
# # Update Data, Keep Method Fixed
#
# **Purpose:** Swap in modern datasets (Pantheon+, DESI BAO, modern H(z)) while keeping the 2012 method unchanged.
#
# ## Checklist
# - [ ] Load Pantheon+ distance moduli/covariance.
# - [ ] Load DESI BAO compressed likelihood or summary constraints.
# - [ ] Run same inference pipeline; compare posteriors to baseline.
# - [ ] Document what changes due to data only.

# %%
# Start here.
