# %% [markdown]
# # Update Method, Keep Data Fixed
#
# **Purpose:** Replace Taylor cosmography with rational approximants / alternative reconstructions on the same modern data.
#
# ## Checklist
# - [ ] Implement Padé / Chebyshev rational distance approximants.
# - [ ] Re-run inference; compare to Taylor results.
# - [ ] Assess stability vs redshift and truncation order.

# %%
# Start here.
