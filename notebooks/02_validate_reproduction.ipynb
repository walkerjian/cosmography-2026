# %% [markdown]
# # Validate Reproduction
#
# **Purpose:** Compare reproduced results against paper tables/figures; quantify deltas and explain mismatches.
#
# ## Checklist
# - [ ] Load reproduced tables and paper targets.
# - [ ] Compute relative/absolute differences for best-fit/mean/2σ.
# - [ ] Overlay reproduced plots vs paper (where possible).
# - [ ] Document any unresolved discrepancies.

# %%
# Start here.
