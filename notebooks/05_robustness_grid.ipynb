# %% [markdown]
# # Robustness Grid & Comparisons
#
# **Purpose:** Run ablations, redshift cuts, dataset combinations; produce summary plots/tables.
#
# ## Checklist
# - [ ] Define grid of dataset combos and z-cuts.
# - [ ] Run batch inference; collect metrics (AIC/BIC where appropriate).
# - [ ] Create final summary table and diagnostic plots.

# %%
# Start here.
