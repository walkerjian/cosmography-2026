# %% [markdown]
# # Reproduce Original Results (2012 Baseline)
#
# **Purpose:** Implement the original cosmography (z and y forms) and reproduce key tables/figures.
#
# ## Checklist
# - [ ] Implement dL(z) and dL(y) series exactly as in paper.
# - [ ] Implement SN likelihood with paper’s nuisance-parameter marginalisation.
# - [ ] Add BAO + shift parameter + H(z) terms.
# - [ ] Run MCMC with paper-like settings; export chains.
# - [ ] Recreate Table 1 and key plots.

# %%
# Start here.
